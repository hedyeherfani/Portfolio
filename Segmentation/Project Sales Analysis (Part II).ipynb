# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
dataset = pd.read_csv('step1.csv',low_memory=False)

# %%
dataset.set_index('InvoiceDate')
# Out:
#                      Unnamed: 0 Invoice StockCode  \
# InvoiceDate
# 2009-12-01 07:45:00           0  489434     85048
# 2009-12-01 07:45:00           1  489434    79323P
# 2009-12-01 07:45:00           2  489434    79323W
# 2009-12-01 07:45:00           3  489434     22041
# 2009-12-01 07:45:00           4  489434     21232
# 2009-12-01 07:45:00           5  489434     22064
# 2009-12-01 07:45:00           6  489434     21871
# 2009-12-01 07:45:00           7  489434     21523
# 2009-12-01 07:46:00           8  489435     22350
# 2009-12-01 07:46:00           9  489435     22349
# 2009-12-01 07:46:00          10  489435     22195
# 2009-12-01 07:46:00          11  489435     22353
# 2009-12-01 09:06:00          12  489436    48173C
# 2009-12-01 09:06:00          13  489436     21755
# 2009-12-01 09:06:00          14  489436     21754
# 2009-12-01 09:06:00          15  489436     84879
# 2009-12-01 09:06:00          16  489436     22119
# ...

# %%
del dataset['Unnamed: 0']

# %%
dataset.set_index('InvoiceDate')
# Out:
#                     Invoice StockCode                          Description  \
# InvoiceDate
# 2009-12-01 07:45:00  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS
# 2009-12-01 07:45:00  489434    79323P                   PINK CHERRY LIGHTS
# 2009-12-01 07:45:00  489434    79323W                  WHITE CHERRY LIGHTS
# 2009-12-01 07:45:00  489434     22041         RECORD FRAME 7" SINGLE SIZE
# 2009-12-01 07:45:00  489434     21232       STRAWBERRY CERAMIC TRINKET BOX
# 2009-12-01 07:45:00  489434     22064           PINK DOUGHNUT TRINKET POT
# 2009-12-01 07:45:00  489434     21871                  SAVE THE PLANET MUG
# 2009-12-01 07:45:00  489434     21523   FANCY FONT HOME SWEET HOME DOORMAT
# 2009-12-01 07:46:00  489435     22350                            CAT BOWL
# 2009-12-01 07:46:00  489435     22349       DOG BOWL , CHASING BALL DESIGN
# 2009-12-01 07:46:00  489435     22195         HEART MEASURING SPOONS LARGE
# ...

# %%
dataset['Revenue'] = dataset['Price']*dataset['Quantity']

# %%
dataset.Quantity.max()
# Out:
# 80995

# %%
dataset.hist(column='Quantity')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fac16cbf810>]],
#       dtype=object)

# %%
dataset['lognorm'] = np.log(dataset['Quantity'])

# %%
dataset.hist(column='lognorm')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fac16f19b90>]],
#       dtype=object)

# %%
dataset.hist(column = 'Price')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fac171a6a10>]],
#       dtype=object)

# %%
dataset.hist(column = 'Revenue')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fac17a3f450>]],
#       dtype=object)

# %%
dataset['Quantity'].plot()

# %%
# Step 11: Plot 'Quantity' against 'Price' with a scatter plot

# %%
dataset.plot(x = 'Quantity', y = 'Price', kind = 'scatter')

# %%
dataset = dataset.to_csv('step2.csv')
